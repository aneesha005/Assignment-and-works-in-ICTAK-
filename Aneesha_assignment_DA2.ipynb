# %% [markdown]
# Impot drivers and Import excel file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/cars_data.xlsx")

# %% [markdown]
# **1.Read the dataset to the python environment**

# %%
data
# Out:
#          Make        Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0      Suzuki       Vitara  Philippine  ...              0.13     200.9       11.5
# 1       Honda        S2000      Henrik  ...              0.02     158.5        8.8
# 2         BMW           Z4      Lebbie  ...              0.24     149.5       14.4
# 3      Toyota       Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4        Ford      Festiva     Glendon  ...              0.18     122.0       14.9
# ...       ...          ...         ...  ...               ...       ...        ...
# 9995    Mazda      Tribute      Cooper  ...              0.14     245.8        8.0
# 9996      GMC  Sierra 2500         Dud  ...              0.11     147.4       12.3
# 9997  Mercury      Mariner     Chariot  ...              0.12     198.1       11.8
# 9998   Daewoo      Leganza       Dynah  ...              0.04     206.7       12.2
# ...

# %% [markdown]
# viewed full data

# %% [markdown]
# **2. Check for the null values present in the dataset.**

# %%
data.isnull()
# Out:
#        Make  Model  Nickname  ...  5-yr Depreciation  Top Speed  0-60 Time
# 0     False  False     False  ...              False      False      False
# 1     False  False     False  ...              False      False      False
# 2     False  False     False  ...              False      False      False
# 3     False  False     False  ...              False      False      False
# 4     False  False     False  ...              False      False      False
# ...     ...    ...       ...  ...                ...        ...        ...
# 9995  False  False     False  ...              False      False      False
# 9996  False  False     False  ...              False      False      False
# 9997  False  False     False  ...              False      False      False
# 9998  False  False     False  ...              False      False      False
# 9999  False  False     False  ...              False      False      False
#
# [10000 rows x 20 columns]

# %% [markdown]
# printed the null values in false

# %% [markdown]
# **3. Plot a bar graph of male vs female buyers participated in the sales.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

result = data.pivot_table (index=['Buyer Gender'],  aggfunc='count')
male_means = (4948)
female_means = (5052)

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, male_means, bar_width,
alpha=opacity,
color='g',
label='Male')

rects2 = plt.bar(index + bar_width, female_means, bar_width,
alpha=opacity,
color='r',
label='female')

plt.xlabel('Male/female')
plt.ylabel('Number of person')
plt.title('Buyer Participation')
plt.xticks(index + bar_width, ('G1'))
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ploted the male vs female buyers participation.female more than male.

# %% [markdown]
# **4. Find the top 5 cars based on their sales price.**

# %%
data.nlargest(5, ['Sale Price'])
# Out:
#             Make      Model   Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 5984  Volkswagen  Jetta III    Rachael  ...              0.06     204.9       12.6
# 1270        Audi         A6      Thorn  ...              0.16     171.3       13.0
# 3460       Lexus         LX      Aldin  ...              0.12     193.7        4.5
# 9032       Mazda       MX-6  Sylvester  ...              0.15     232.0        3.9
# 302        Lexus         ES       Brig  ...              0.21     228.1        4.7
#
# [5 rows x 20 columns]

# %% [markdown]
# here printed the largest sales priced 5 cars details

# %% [markdown]
# **5. Find the least 5 cars based on their Resell price.**

# %%
data.nsmallest(5,['Resell Price'])
# Out:
#             Make        Model Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 2446   Chevrolet         1500  Corenda  ...              0.25     239.6       11.2
# 4933         GMC  Savana 1500     Lark  ...              0.01     158.7        9.0
# 566       Jaguar           XF   Payton  ...              0.19     249.3        6.9
# 2538  Mitsubishi       3000GT     Thia  ...              0.14     222.0       10.3
# 5869    Infiniti          G37    Sonny  ...              0.04     131.6       12.3
#
# [5 rows x 20 columns]

# %% [markdown]
# smallest resel priced 5 cars and their complete details are printed

# %% [markdown]
# # New section
